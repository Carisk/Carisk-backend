# %%
import pandas as pd

# %%
data = pd.read_csv('datatran2019.csv', encoding="ISO-8859-1", sep=";", decimal=',')

# %%
df = pd.DataFrame(data=data)

# %%
df.head(10)
# Out:
#          id data_inversa   dia_semana   horario  uf     br     km  \
# 0  182210.0   2019-01-01  terça-feira  01:30:00  SP  116.0  218.0
# 1  182211.0   2019-01-01  terça-feira  01:30:00  PR  373.0  177.3
# 2  182212.0   2019-01-01  terça-feira  00:45:00  SC  101.0   16.0
# 3  182214.0   2019-01-01  terça-feira  00:00:00  CE   20.0  429.5
# 4  182215.0   2019-01-01  terça-feira  01:00:00  MG  381.0  327.0
# 5  182216.0   2019-01-01  terça-feira  01:50:00  SC  470.0   42.6
# 6  182217.0   2019-01-01  terça-feira  01:30:00  MS  163.0  721.5
# 7  182219.0   2019-01-01  terça-feira  00:50:00  GO   50.0  280.3
# 8  182220.0   2019-01-01  terça-feira  02:25:00  GO   60.0  172.0
# 9  182223.0   2019-01-01  terça-feira  02:15:00  RS  386.0   73.7
#
#                municipio                                     causa_acidente  \
# 0              GUARULHOS                        Falta de Atenção à Condução
# 1           PONTA GROSSA                        Falta de Atenção à Condução
# ...

# %% [markdown]
# #### Tipos de Acidentes
#     0 - Colisões
#     1 - Saida da pista (Saída de leito carroçável)
#     2 - Acidente com animais
#     3 - Acidentes com pedestres
#     4 - Capotamento e tombamento
#     5 - Engavetamento
#     6 - Derramamento de carga
#     7 - Danos eventuais
#
# #### Dia da Semana
#     0 - Domingo
#     1 - Segunda-feira
#     2 - Terça-feira
#     3 - Quarta-feira
#     4 - Quinta-feira
#     5 - Sexta-feira
#     6 - Sábado
#
# #### Estado
#     11 - Rondônia - RO
#     12 - Acre - AC
#     13 - Amazonas - AM
#     14 - Roraima -RR
#     15 - Pará - PA
#     16 - Amapá - AP
#     17 - Tocantins - TO
#     21 - Maranhão - MA
#     22 - Piauí - PI
#     23 - Ceará - CE
#     24 - Rio Grande do Norte - RN
#     25 - Paraíba - PB
#     26 - Pernambuco - PE
#     27 - Alagoas - AL
#     28 - Sergipe - SE
#     29 - Bahia - BA
#     31 - Minas Gerais -MG
#     32 - Espírito Santo - ES
#     33 - Rio de Janeiro - RJ
#     35 - São Paulo - SP
#     41 - Paraná - PR
#     42 - Santa Catarina - SC
#     43 - Rio Grande do Sul - RS
#     50 - Mato Grosso do Sul - MS
#     51 - Mato Grosso - MT
#     52 - Goiás - GO
#     53 - Distrito Federal - DF
#
# #### Fases do dia
#     0 - Plena Noite
#     1 - Amanhecer
#     2 - Pleno dia
#     3 - Anoitecer
#
# #### Clima
#
#     0 - Céu Claro
#     1 - Nublado
#     2 - Chuva
#     3 - Garoa/Chuvisco
#     4 - Ignorado
#     5 - Nevoeiro/Neblina
#     6 - Vento
#     7 - Sol
#     8 - Granizo
#     9 - Neve

# %%
cleanup ={
    "tipo_acidente": {
        'Colisão com objeto estático': 0,
        'Colisão traseira': 0,
        'Colisão transversal': 0,
        'Saída de leito carroçável': 1,
        'Atropelamento de Animal': 2,
        'Atropelamento de Pedestre': 3,
        'Colisão frontal': 0,
        'Colisão lateral': 0,
        'Queda de ocupante de veículo': 7,
        'Incêndio': 7,
        'Capotamento': 4,
        'Engavetamento': 5,
        'Tombamento': 4,
        'Derramamento de carga': 6,
        'Colisão com objeto em movimento': 0,
        'Danos eventuais': 7,
    },
    "dia_semana":{
        'domingo': 0,
        'segunda-feira': 1,
        'terça-feira': 2,
        'quarta-feira': 3,
        'quinta-feira': 4,
        'sexta-feira': 5,
        'sábado': 6,  
    },
    "uf": {
        "RO":11,
        "AC":12,
        "AM":13,
        "RR":14,
        "PA":15,
        "AP":16,
        "TO":17,
        "MA":21,
        "PI":22,
        "CE":23,
        "RN":24,
        "PB":25,
        "PE":26,
        "AL":27,
        "SE":28,
        "BA":29,
        "MG":31,
        "ES":32,
        "RJ":33,
        "SP":35,
        "PR":41,
        "SC":42,
        "RS":43,
        "MS":50,
        "MT":51,
        "GO":52,
        "DF":53,
    },
    'fase_dia':{
        "Plena Noite": 0,
        "Amanhecer": 1, 
        "Pleno dia": 2,
        "Anoitecer": 3,
    },
    'condicao_metereologica':{
        "Céu Claro": 0,
        "Nublado": 1,
        "Chuva": 2,
        "Garoa/Chuvisco": 3,
        "Ignorado": 4,
        "Nevoeiro/Neblina": 5,
        "Vento": 6,
        "Sol": 7,
        "Granizo":8,
        "Neve":9,
    }
}

# %%
df.replace(cleanup, inplace=True)
df.head(20)
# Out:
#           id data_inversa  dia_semana   horario  uf     br     km  \
# 0   182210.0   2019-01-01           2  01:30:00  35  116.0  218.0
# 1   182211.0   2019-01-01           2  01:30:00  41  373.0  177.3
# 2   182212.0   2019-01-01           2  00:45:00  42  101.0   16.0
# 3   182214.0   2019-01-01           2  00:00:00  23   20.0  429.5
# 4   182215.0   2019-01-01           2  01:00:00  31  381.0  327.0
# 5   182216.0   2019-01-01           2  01:50:00  42  470.0   42.6
# 6   182217.0   2019-01-01           2  01:30:00  50  163.0  721.5
# 7   182219.0   2019-01-01           2  00:50:00  52   50.0  280.3
# 8   182220.0   2019-01-01           2  02:25:00  52   60.0  172.0
# 9   182223.0   2019-01-01           2  02:15:00  43  386.0   73.7
# 10  182225.0   2019-01-01           2  02:00:00  31   50.0   77.3
# 11  182226.0   2019-01-01           2  02:10:00  35  101.0   39.5
# 12  182227.0   2019-01-01           2  02:30:00  41  376.0    7.5
# ...

# %%
df.to_csv('data_pre.csv')

# %% [markdown]
#  ### EDA

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
fig, axes = plt.subplots(figsize=(15, 10))

sns.countplot(x='tipo_acidente', data=df)
# Out:
# <AxesSubplot:xlabel='tipo_acidente', ylabel='count'>

# %%
fig, axes = plt.subplots(nrows=1, ncols=4, figsize=(28, 6))

sns.countplot(ax=axes[0], x='dia_semana', data=df)
sns.countplot(ax=axes[1], x='uf', data=df)
sns.countplot(ax=axes[2], x='fase_dia', data=df)
sns.countplot(ax=axes[3], x='condicao_metereologica', data=df)
# Out:
# <AxesSubplot:xlabel='condicao_metereologica', ylabel='count'>
